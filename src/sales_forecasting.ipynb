# %%
import pandas as pd
from prophet import Prophet

# %%
orders = pd.read_csv("/kaggle/input/datasets/sahil8989/orders/orders_clean.csv")

orders["order_time"] = pd.to_datetime(orders["order_time"])

# %%
daily_sales = orders.groupby(

    orders["order_time"].dt.date

)["total_usd"].sum().reset_index()

daily_sales.columns = ["ds", "y"]

daily_sales["ds"] = pd.to_datetime(daily_sales["ds"])

# %%
model = Prophet()

model.fit(daily_sales)
# Out:
# 10:15:50 - cmdstanpy - INFO - Chain [1] start processing
# 10:15:50 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=90)

forecast = model.predict(future)

# %%
forecast[["ds", "yhat"]].to_csv(

    "sales_forecast.csv",
    index=False

)

print("Sales forecast generated")
# Out:
# Sales forecast generated
